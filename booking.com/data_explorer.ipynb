# %%
import sqlite3
import pandas as pd

with sqlite3.connect('stanford_qd_sample.db') as con:
    descriptions = pd.read_sql('''select * from descriptions''', con)
    facilities = pd.read_sql('''select * from facilities''', con)
    landmarks = pd.read_sql('''select * from landmarks''', con)

# %%
facilities
# Out:
#        property_id  facility_id                                name  \
# 0                0            0              Parking (fee required)
# 1                0            3                        Room-service
# 2                0            5                                 Bar
# 3                0            6                  24 hour Front Desk
# 4                0           11                          Newspapers
# 5                0           14                   Non Smoking Rooms
# 6                0           17                     Business Center
# 7                0           19                             Laundry
# 8                0           20                        Dry Cleaning
# 9                0           26                     Ironing Service
# 10               0           30                       Valet-Parking
# 11               0           42                        Bicycle rent
# 12               0           51                           Tour desk
# ...
